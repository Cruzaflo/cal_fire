# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv("mapdataall.csv")
df
# Out:
#           incident_name  incident_is_final incident_date_last_update  \
# 0           Bridge Fire               True              1/9/18 13:46
# 1             Pala Fire               True             9/16/20 14:07
# 2            River Fire               True             2/28/13 20:00
# 3         Fawnskin Fire               True              4/22/13 9:00
# 4             Gold Fire               True               5/1/13 7:00
# ...                 ...                ...                       ...
# 1701   Shackleford Fire              False             9/16/20 20:54
# 1702      Bullfrog Fire              False             9/12/20 17:29
# 1703           Fox Fire              False             9/16/20 11:08
# 1704  San Antonio Fire               False             9/16/20 16:00
# 1705         Snow Fire               False             9/17/20 17:04
#
#      incident_date_created                       incident_administrative_unit  \
# ...

# %%
year = dt.date.today().year
year
# Out:
# 2020

# %%
df['year'] = pd.DatetimeIndex(df['incident_dateonly_created']).year
df.head()
# Out:
#    incident_name  incident_is_final incident_date_last_update  \
# 0    Bridge Fire               True              1/9/18 13:46
# 1      Pala Fire               True             9/16/20 14:07
# 2     River Fire               True             2/28/13 20:00
# 3  Fawnskin Fire               True              4/22/13 9:00
# 4      Gold Fire               True               5/1/13 7:00
#
#   incident_date_created          incident_administrative_unit  \
# 0        10/31/17 11:22       Shasta-Trinity National Forest
# 1         5/24/09 14:56               CAL FIRE San Diego Unit
# 2          2/24/13 8:16          CAL FIRE San Bernardino Unit
# 3         4/20/13 17:30        San Bernardino National Forest
# 4         4/30/13 12:59  CAL FIRE Madera-Mariposa-Merced Unit
#
#    incident_administrative_unit_url incident_county  \
# 0                               NaN          Shasta
# 1                               NaN       San Diego
# 2                               NaN            Inyo
# ...

# %%
acres_year = df.groupby("year")["incident_acres_burned"].sum().reset_index()
acres_year.head(10)
# Out:
#    year  incident_acres_burned
# 0  2009                    122
# 1  2013                 496937
# 2  2014                 297186
# 3  2015                 413462
# 4  2016                 452406
# 5  2017                1455280
# 6  2018                1571007
# 7  2019                 285439
# 8  2020                2882362
# 9  2069                     57

# %%
acres_2016df = acres_year[(acres_year["year"] > 2015) & (acres_year["year"] < 2021)]
acres_2016df
# Out:
#    year  incident_acres_burned
# 4  2016                 452406
# 5  2017                1455280
# 6  2018                1571007
# 7  2019                 285439
# 8  2020                2882362

# %%
import sqlite3

# %%
conn = sqlite3.connect('Fires2016-2020.db')
c = conn.cursor()

# %%
c.execute('CREATE TABLE FIRES (year, incident_acres_burned)')
conn.commit()
